# %%
import pandas as pd

# %%
file_path ='/content/2023_merged_without_nodate_files.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

print(df.head())
# Out:
#                                                  URL  Unique Clicks  \
# 0  https://awginc1.box.com/s/14uktcahn8fb77gt8zno...            136
# 1  https://awgincpromotions.my.salesforce-sites.c...             56
# 2  https://awginc1.app.box.com/s/jvfk2ndjhwf72jur...             20
# 3  https://awginc1.box.com/s/csnxppp31eye0p93wcc9...             35
# 4  https://awginc1.box.com/s/aip9t3mx8nirbumlfgxx...             24
#
#    Total Clicks  % of Sent  % of Views       Date
# 0           339      0.033       0.302 2023-07-05
# 1            86      0.014       0.077 2023-07-05
# 2            54      0.005       0.048 2023-07-05
# 3            47      0.009       0.042 2023-07-05
# 4            44      0.006       0.039 2023-07-05

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_selected = df[["% of Sent", "Total Clicks"]]
df_selected = df_selected.apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# Correlation Heatmap 2023

# %%
plt.figure(figsize=(5,4))
sns.heatmap(df_selected.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap between % of Sent and Total Click (2023)")

plt.show()


df['Date'] = pd.to_datetime(df['Date'])

# %%
# Pearson Correlation Coefficient
overall_correlation = df[['Total Clicks', '% of Sent']].corr().iloc[0, 1]
print(f"Total Clicks 和 % of Sent Pearson Correlation Coefficient: {overall_correlation:.2f}")


df_sorted = df.sort_values('Date')
# Out:
# Total Clicks 和 % of Sent Pearson Correlation Coefficient: 0.85

# %%
# time series plot
plt.figure(figsize=(12, 5))
plt.plot(df_sorted['Date'], df_sorted['Total Clicks'], label='Total Clicks', marker='o', linestyle='-')
plt.plot(df_sorted['Date'], df_sorted['% of Sent'] * 1000, label='% of Sent (scaled)', marker='s', linestyle='-')

plt.xlabel('Date')
plt.ylabel('Values (Clicks / Scaled % of Sent)')
plt.title(f'Time Series of Total Clicks and % of Sent (Correlation: {overall_correlation:.2f})')
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
file_path = '/content/2024-Links.xlsx'
df = pd.read_excel(file_path, engine='openpyxl')

print(df.head())
# Out:
#                                                  URL  Unique Clicks  \
# 0  https://awginc1.box.com/s/wham93b9mubndfjkw6wx...           26.0
# 1  https://awginc1.box.com/s/ar6c09jo2yt2w0nzveoo...           24.0
# 2  https://awginc1.box.com/s/6ppjlrfdfqwivhv68u1t...           12.0
# 3  https://awginc1.box.com/s/8k1pimreyn47k7t9hdph...            9.0
# 4  https://awginc1.box.com/s/way03128r89kzhe3d5yu...            8.0
#
#    Total Clicks  % of Sent  % of Views       Date
# 0          45.0      0.006       0.048 2024-08-20
# 1          43.0      0.005       0.046 2024-08-20
# 2          19.0      0.003       0.020 2024-08-20
# 3          18.0      0.002       0.019 2024-08-20
# 4          16.0      0.002       0.017 2024-08-20

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_selected = df[["% of Sent", "Total Clicks"]]
df_selected = df_selected.apply(pd.to_numeric, errors='coerce')


plt.figure(figsize=(5,4))
sns.heatmap(df_selected.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap between % of Sent and Total Click (2024)")

plt.show()

# %%
# Pearson Correlation Coefficient
df['Date'] = pd.to_datetime(df['Date'])
overall_correlation = df[['Total Clicks', '% of Sent']].corr().iloc[0, 1]
print(f"Total Clicks 和 % of Sent Pearson Correlation Coefficient: {overall_correlation:.2f}")
df_sorted = df.sort_values('Date')
# Out:
# Total Clicks 和 % of Sent Pearson Correlation Coefficient: 0.89

# %%
# time series plot
plt.figure(figsize=(12, 5))
plt.plot(df_sorted['Date'], df_sorted['Total Clicks'], label='Total Clicks', marker='o', linestyle='-')
plt.plot(df_sorted['Date'], df_sorted['% of Sent'] * 1000, label='% of Sent (scaled)', marker='s', linestyle='-')

plt.xlabel('Date')
plt.ylabel('Values (Clicks / Scaled % of Sent)')
plt.title(f'Time Series of Total Clicks and % of Sent (Correlation: {overall_correlation:.2f})')
plt.legend()
plt.xticks(rotation=45)
plt.grid()
plt.show()
